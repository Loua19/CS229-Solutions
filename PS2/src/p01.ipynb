# %%
import numpy as np
import matplotlib.pyplot as plt
import util

# %%
Xa, Ya = util.load_csv('../data/ds1_a.csv', add_intercept=True)
Xb, Yb = util.load_csv('../data/ds1_b.csv', add_intercept=True)

# %%
plt.figure()
plt.plot(Xa[Ya == 1, -2], Xa[Ya == 1, -1], 'bx')
plt.plot(Xa[Ya == -1, -2], Xa[Ya == -1, -1], 'ro')
plt.xlabel('x1')
plt.ylabel('x2')
plt.suptitle('Data set A')
# Out:
# Text(0.5, 0.98, 'Data set A')

# %%
plt.figure()
plt.plot(Xb[Yb == 1, -2], Xb[Yb == 1, -1], 'bx')
plt.plot(Xb[Yb == -1, -2], Xb[Yb == -1, -1], 'ro')
plt.xlabel('x1')
plt.ylabel('x2')
plt.suptitle('Data set B')
# Out:
# Text(0.5, 0.98, 'Data set B')

# %% [markdown]
# b) Dataset B is linearly separable whereas dataset A is not. Judging by the code in the method calc_grad of p01_lr.py we observe that in the case that the data is linearly separable, the algorithm approximates $\theta_{j+1} = C\theta_j$ for a fixed constant C. This is confirmed by debugging p01_lr.py with a breakpoint on line 24.

# %% [markdown]
# c) To solve this we may implement solutions (ii), (iv) or (v).

# %% [markdown]
# d) SVMs are not vulnerable to datasets like B as if $\theta$ linearly separates the data then geometric margin $g(\theta)$ is minimal.
